# %% [markdown]
# <a href="https://colab.research.google.com/github/jawahar17/Artificial-Intelligence/blob/master/facerecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 4.9MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.3-cp36-none-any.whl size=10043491 sha256=f3ae3d5f406ce00b468e03f5f5a72c4149ac943feddddc18b906c575ff1d8b17
#   Stored in directory: /root/.cache/pip/wheels/c9/83/ca/701a48deacbc78758f33173252feb97297316c40af783264e2
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12073 sha256=9319d5840245021671f2bd00b6649cffcd54d040202173f93a5c6484e4ea9907
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = 'bean.jpg'
im =cv2.imread(image_path)
plt.imshow(im)
plt.show()
faces, confidences = cv.detect_face(im)
for face in faces:
  (startX,startY) = face[0],face[1]
  (endX,endY) =face[2],face[3]
  cv2.rectangle(im, (startX,startY), (endX,endY), (0,225,0), 2)
  plt.imshow(im)
  plt.show()
